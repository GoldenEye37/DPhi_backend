# %% [markdown]
# <a href="https://colab.research.google.com/github/GoldenEye37/DPhi_backend/blob/main/dog_breed_identification_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
